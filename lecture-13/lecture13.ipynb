# %%
import pandas

x = pandas.read_csv("http://danham.me/r/data/satellite-data.csv")
print(x.head())
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-6-a97c92a3588c> in <module>()
#       1 import pandas
#       2
# ----> 3 x = pandas.read_csv("http://danham.me/r/data/satellite-data.csv")
#       4 print(x.head())
#
# ...
